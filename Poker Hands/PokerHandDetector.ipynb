# %%
from ultralytics import YOLO
import cv2 as cv
import cvzone
import math
import PokerHandFunction

# %%
cap = cv.VideoCapture(0)
cap.set(3, 1280)
cap.set(4, 720)
# Out:
# True

# %%
model = YOLO("PokerCards.pt")

classNames = ['10C', '10D', '10H', '10S',
              '2C', '2D', '2H', '2S',
              '3C', '3D', '3H', '3S',
              '4C', '4D', '4H', '4S',
              '5C', '5D', '5H', '5S',
              '6C', '6D', '6H', '6S',
              '7C', '7D', '7H', '7S',
              '8C', '8D', '8H', '8S',
              '9C', '9D', '9H', '9S',
              'AC', 'AD', 'AH', 'AS',
              'JC', 'JD', 'JH', 'JS',
              'KC', 'KD', 'KH', 'KS',
              'QC', 'QD', 'QH', 'QS']

# %%
while True:
    success, img = cap.read()
    results = model(img, stream=True)
    hand = []
    for r in results:
        boxes = r.boxes
        for box in boxes:
            # Bounding Box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
           
            w, h = x2 - x1, y2 - y1
            cvzone.cornerRect(img, (x1, y1, w, h))
            
            # Confidence
            conf = math.ceil((box.conf[0] * 100)) / 100
            # Class Name
            cls = int(box.cls[0])
 
            cvzone.putTextRect(img, f'{classNames[cls]} {conf}', (max(0, x1), max(35, y1)), scale=1, thickness=1)
 
            if conf > 0.5:
                hand.append(classNames[cls])
 
    print(hand)
    hand = list(set(hand)) # creates a lisy of unique values
    print(hand)
    if len(hand) == 5:
        results = PokerHandFunction.findPokerHand(hand)
        print(results)
        cvzone.putTextRect(img, f'Your Hand: {results}', (300, 75), scale=2, thickness=3)
 
    cv.imshow("Image", img)
    cv.waitKey(1)
# Out:
# 0: 384x640 (no detections), 3022.3ms
# Speed: 11.2ms preprocess, 3022.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# []
# []
#
# 0: 384x640 (no detections), 3020.6ms
# Speed: 0.0ms preprocess, 3020.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# []
# []
#
# 0: 384x640 (no detections), 1885.4ms
# Speed: 5.9ms preprocess, 1885.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# []
# []
#
# 0: 384x640 (no detections), 1112.5ms
# Speed: 0.0ms preprocess, 1112.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# []
# []
#
# 0: 384x640 (no detections), 1085.8ms
# Speed: 0.0ms preprocess, 1085.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# []
# []
#
# 0: 384x640 (no detections), 1078.4ms
# Speed: 0.0ms preprocess, 1078.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# []
# []
#
# 0: 384x640 (no detections), 1078.2ms
# ...
